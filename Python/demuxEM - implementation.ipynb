# %% [markdown]
# <h1> Demux-EM </h1>
# <br>
# Simple visual implementation

# %%
import h5py
import numpy as np
import pyreadr
import rpy2
import pandas as pd
from rpy2.robjects.packages import importr
from rpy2.robjects import pandas2ri
import rpy2.robjects as robjects

# %% [markdown]
# <h3> Get HTO Counts Matrix and UMI Matrix </h3>
# Both matrices come from .rds objects and need to be transformed into .csv and hdf5

# %%
r_hto_matrix = pyreadr.read_r('/Users/mylenemarianagonzalesandre/Development/Bachelor-Thesis/demultiplex-pipeline/data/pbmc_hto_mtx.rds')

# %%
df = r_hto_matrix[None]

# %%
df.head()
# Out:
#        AGGCCACAGCGTCTAT  ATTGGTGAGTTCGCAT  GTGCAGCTCAGTCCCT  TAGTTGGGTCATACTG  \
# HTO_A                 3                19                 3                 6
# HTO_B                 0                17                13                17
# HTO_C                 1               110                48                 9
# HTO_D                10                50                 8                33
# HTO_E                10                53                 0                22
#
#        TTCTTAGAGAAGGCCT  TAGACCAGTGTAACGG  TGACTAGTCAGTACGT  AGGGATGTCCAAAGTC  \
# HTO_A                 7                 2                22                 0
# HTO_B                31                10                 5                13
# HTO_C                26                 7                29                12
# HTO_D              1769                17                17              4760
# HTO_E                11              5418                 2                18
#
# ...

# %%
# Out:
# R[write to console]: Lade nötiges Paket: Matrix

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [15], in <cell line: 3>()
#       1 readRDS = robjects.r['readRDS']
#       2 df = readRDS('/Users/mylenemarianagonzalesandre/Development/Bachelor-Thesis/demultiplex-pipeline/data/pbmc_umi_mtx.rds')
# ----> 3 df = pandas2ri.rpy2py_dataframe(df)
#
# File /opt/anaconda3/envs/demul/lib/python3.9/site-packages/rpy2/robjects/pandas2ri.py:233, in rpy2py_dataframe(obj)
#     230 @rpy2py.register(DataFrame)
#     231 def rpy2py_dataframe(obj):
#     232     items = OrderedDict((k, rpy2py(v) if isinstance(v, Sexp) else v)
# --> 233                         for k, v in obj.items())
#     234     res = PandasDataFrame.from_dict(items)
#     235     res.index = obj.rownames
#
# AttributeError: 'RS4' object has no attribute 'items'
