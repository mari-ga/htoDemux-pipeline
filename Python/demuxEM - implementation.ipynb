# %% [markdown]
# <h1> Demux-EM </h1>
# <br>
# Simple visual implementation

# %%
import h5py
import numpy as np
import pandas as pd
import pegasusio as io
from demuxEM.tools import *

# %% [markdown]
# <h3> Get HTO Counts Matrix and UMI Matrix </h3>
# Both matrices come from .rds objects and were transformed into .csv and hdf5 during the pre processing step

# %%
hto_mat = pd.read_csv("/Users/mylenemarianagonzalesandre/Development/Bachelor-Thesis/demultiplex-pipeline/data/hto_matrix.csv")

# %%
hto_mat.head()
# Out:
#   Unnamed: 0  AGGCCACAGCGTCTAT  ATTGGTGAGTTCGCAT  GTGCAGCTCAGTCCCT  \
# 0      HTO_A                 3                19                 3
# 1      HTO_B                 0                17                13
# 2      HTO_C                 1               110                48
# 3      HTO_D                10                50                 8
# 4      HTO_E                10                53                 0
#
#    TAGTTGGGTCATACTG  TTCTTAGAGAAGGCCT  TAGACCAGTGTAACGG  TGACTAGTCAGTACGT  \
# 0                 6                 7                 2                22
# 1                17                31                10                 5
# 2                 9                26                 7                29
# 3                33              1769                17                17
# 4                22                11              5418                 2
#
#    AGGGATGTCCAAAGTC  TGTCCCAGTCTCCACT  ...  AGCGTCGAGACGCACA  \
# ...

# %%
filename = "/Users/mylenemarianagonzalesandre/Development/Bachelor-Thesis/demultiplex-pipeline/data/umi_matrix.h5"

with h5py.File(filename, "r") as f:
    # List all groups
    print("Keys: %s" % f.keys())
    a_group_key = list(f.keys())[0]

    # Get the data
    data = list(f[a_group_key])
# Out:
# Keys: <KeysViewHDF5 ['conversion?']>

# %%
pegasus.demultiplex(rna_data, hto_mat, min_signal=10.0, alpha=0.0, alpha_noise=1.0, tol=1e-06, n_threads=1)
# Out:
# '/Users/mylenemarianagonzalesandre/Development/Bachelor-Thesis/demultiplex-pipeline/data/umi_matrix.h5'
